# %%
from keras.datasets import fashion_mnist
(x_train, y_train), (x_test,y_test) = fashion_mnist.load_data()
x_train.shape
#y_train.shape
#x_test.shape
#y_test.shape
# Out:
# (10000,)

# %%
class_names = ['T-shirt/Top','Trousers','Pullower','Press','Coat','Sandal','Shirt','Sneaker','Bag','Ankle boot']

# %%
import matplotlib.pyplot as plt
plt.imshow (x_train[113])
plt.show()
print(class_names[y_train[113]])
# Out:
# Shirt

# %%
from keras import models
from keras import layers
model = models.Sequential()
model.add(layers.Dense(512,activation = 'relu', input_shape =(28*28,)))
model.add(layers.Dense(10,activation = 'softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               401920
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________

# %%
x_train = x_train.reshape(60000,28*28)
x_train = x_train.astype('float32')/255
x_test = x_test.reshape(10000,28*28)
x_test = x_test.astype('float32')/255
x_train.shape
# Out:
# (60000, 784)

# %%
from keras.utils import to_categorical
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
y_train.shape
# Out:
# (60000, 10)

# %%
model.compile(optimizer= 'rmsprop', loss = 'categorical_crossentropy', metrics = ['accuracy'])
model.fit(x_train, y_train, epochs = 100, batch_size=128)
# Out:
# Epoch 1/100
# 469/469 [==============================] - 3s 6ms/step - loss: 1.0181 - accuracy: 0.5979
# Epoch 2/100
# 469/469 [==============================] - 3s 6ms/step - loss: 1.0170 - accuracy: 0.5970
# Epoch 3/100
# 469/469 [==============================] - 3s 6ms/step - loss: 1.0156 - accuracy: 0.5972
# Epoch 4/100
# 469/469 [==============================] - 3s 6ms/step - loss: 1.0145 - accuracy: 0.6011
# Epoch 5/100
# 469/469 [==============================] - 3s 6ms/step - loss: 1.0133 - accuracy: 0.5961
# Epoch 6/100
# 469/469 [==============================] - 3s 6ms/step - loss: 1.0121 - accuracy: 0.5990
# Epoch 7/100
# 469/469 [==============================] - 3s 6ms/step - loss: 1.0109 - accuracy: 0.6002
# Epoch 8/100
# 469/469 [==============================] - 3s 7ms/step - loss: 1.0097 - accuracy: 0.5999
# Epoch 9/100
# 469/469 [==============================] - 3s 7ms/step - loss: 1.0086 - accuracy: 0.6009
# Epoch 10/100
# 469/469 [==============================] - 3s 6ms/step - loss: 1.0074 - accuracy: 0.6008
# Epoch 11/100
# 469/469 [==============================] - 3s 6ms/step - loss: 1.0062 - accuracy: 0.5998
# Epoch 12/100
# 469/469 [==============================] - 3s 6ms/step - loss: 1.0050 - accuracy: 0.6002
# Epoch 13/100
# 469/469 [==============================] - 3s 6ms/step - loss: 1.0039 - accuracy: 0.6014
# Epoch 14/100
# 469/469 [==============================] - 3s 6ms/step - loss: 1.0028 - accuracy: 0.6033
# Epoch 15/100
# 469/469 [==============================] - 3s 6ms/step - loss: 1.0017 - accuracy: 0.6022
# Epoch 16/100
# 469/469 [==============================] - 3s 6ms/step - loss: 1.0006 - accuracy: 0.6044
# Epoch 17/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9995 - accuracy: 0.6020
# Epoch 18/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9983 - accuracy: 0.6049
# Epoch 19/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9974 - accuracy: 0.6041
# Epoch 20/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9963 - accuracy: 0.6041
# Epoch 21/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9952 - accuracy: 0.6049
# Epoch 22/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9941 - accuracy: 0.6056
# Epoch 23/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9930 - accuracy: 0.6054
# Epoch 24/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9920 - accuracy: 0.6052
# Epoch 25/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9907 - accuracy: 0.6085
# Epoch 26/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9899 - accuracy: 0.6060
# Epoch 27/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9888 - accuracy: 0.6059
# Epoch 28/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9878 - accuracy: 0.6068
# Epoch 29/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9869 - accuracy: 0.6090
# Epoch 30/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.9857 - accuracy: 0.6090
# Epoch 31/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9847 - accuracy: 0.6085
# Epoch 32/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9837 - accuracy: 0.6074
# Epoch 33/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9827 - accuracy: 0.6103
# Epoch 34/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9816 - accuracy: 0.6118
# Epoch 35/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9807 - accuracy: 0.6118
# Epoch 36/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9798 - accuracy: 0.6111
# Epoch 37/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9789 - accuracy: 0.6094
# Epoch 38/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9777 - accuracy: 0.6127
# Epoch 39/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9767 - accuracy: 0.6148
# Epoch 40/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9758 - accuracy: 0.6108
# Epoch 41/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9749 - accuracy: 0.6127
# Epoch 42/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9741 - accuracy: 0.6120
# Epoch 43/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9732 - accuracy: 0.6148
# Epoch 44/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9722 - accuracy: 0.6162
# Epoch 45/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9714 - accuracy: 0.6125
# Epoch 46/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9704 - accuracy: 0.6124
# Epoch 47/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9695 - accuracy: 0.6152
# Epoch 48/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9686 - accuracy: 0.6181
# Epoch 49/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9678 - accuracy: 0.6148
# Epoch 50/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9669 - accuracy: 0.6182
# Epoch 51/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9659 - accuracy: 0.6186
# Epoch 52/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9651 - accuracy: 0.6146
# Epoch 53/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.9643 - accuracy: 0.6198
# Epoch 54/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9633 - accuracy: 0.6147
# Epoch 55/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9624 - accuracy: 0.6180
# Epoch 56/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9616 - accuracy: 0.6247
# Epoch 57/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.9609 - accuracy: 0.6168
# Epoch 58/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.9599 - accuracy: 0.6205
# Epoch 59/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9592 - accuracy: 0.6216
# Epoch 60/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9585 - accuracy: 0.6212
# Epoch 61/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9576 - accuracy: 0.6217
# Epoch 62/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9567 - accuracy: 0.6206
# Epoch 63/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9561 - accuracy: 0.6234
# Epoch 64/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9552 - accuracy: 0.6224
# Epoch 65/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9542 - accuracy: 0.6211
# Epoch 66/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9535 - accuracy: 0.6276
# Epoch 67/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9527 - accuracy: 0.6226
# Epoch 68/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9520 - accuracy: 0.6234
# Epoch 69/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9512 - accuracy: 0.6262
# Epoch 70/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9503 - accuracy: 0.6208
# Epoch 71/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9497 - accuracy: 0.6298
# Epoch 72/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9489 - accuracy: 0.6296
# Epoch 73/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9481 - accuracy: 0.6296
# Epoch 74/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9474 - accuracy: 0.6238
# Epoch 75/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.9465 - accuracy: 0.6279
# Epoch 76/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.9457 - accuracy: 0.6304
# Epoch 77/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.9452 - accuracy: 0.6328
# Epoch 78/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.9444 - accuracy: 0.6293
# Epoch 79/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.9437 - accuracy: 0.6322
# Epoch 80/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9429 - accuracy: 0.6324
# Epoch 81/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9423 - accuracy: 0.6295
# Epoch 82/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.9415 - accuracy: 0.6353
# Epoch 83/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9408 - accuracy: 0.6311
# Epoch 84/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9401 - accuracy: 0.6355
# Epoch 85/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9395 - accuracy: 0.6345
# Epoch 86/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9387 - accuracy: 0.6317
# Epoch 87/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9379 - accuracy: 0.6351
# Epoch 88/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9372 - accuracy: 0.6359
# Epoch 89/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9366 - accuracy: 0.6357
# Epoch 90/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9360 - accuracy: 0.6352
# Epoch 91/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9354 - accuracy: 0.6338
# Epoch 92/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9346 - accuracy: 0.6379
# Epoch 93/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9339 - accuracy: 0.6372
# Epoch 94/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9334 - accuracy: 0.6384
# Epoch 95/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9326 - accuracy: 0.6378
# Epoch 96/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9320 - accuracy: 0.6368
# Epoch 97/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9314 - accuracy: 0.6398
# Epoch 98/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9306 - accuracy: 0.6405
# Epoch 99/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9299 - accuracy: 0.6395
# Epoch 100/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9293 - accuracy: 0.6399

# %%
test_loss, test_acc = model.evaluate(x_test,y_test)
print('Test accurary:',test_acc)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.9308 - accuracy: 0.6343
# Test accurary: 0.6342999935150146

# %%
class_names = ["T-shirt/Top", "Trousers", "Pullover", "Press", "coat", "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

# %%
from tensorflow.keras.utils import load_img
from keras.utils.image_utils import img_to_array
import numpy as np

url = "hi.jpg"
img = load_img(url, target_size=(28,28))
plt.imshow(img)
img = img_to_array(img)
img = img.reshape(1, 28, 28, 3)
img = img.astype("float32")
img = img/255
img = img.reshape(-1, 784)

# %%
prediction = model.predict(img)
np.argmax(prediction, axis=1)
index = -1
max_value = -1

for i in range(0, len(prediction[0])):
  if max_value < prediction[0][i]:
    max_value = prediction[0][i]
    index = i
print(prediction)
print("Kết quả: ", class_names[index])
print("Độ chính xác: ", max_value)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-42bb06351414> in <module>
# ----> 1 prediction = model.predict(img)
#       2 np.argmax(prediction, axis=1)
#       3 index = -1
#       4 max_value = -1
#       5
#
# NameError: name 'model' is not defined

# %% [markdown]
# # Mục mới

# %% [markdown]
# # Mục mới

# %% [markdown]
# # Mục mới
